# %%
import requests
import pprint as pp

url = "https://wnba-api.p.rapidapi.com/wnbabox"

querystring = {"gameId":"401244185"}

headers = {
	"x-rapidapi-key": "769b17cbe4msh6c112b3e9b5c97ap1e591ejsn89cbe3f5b297",
	"x-rapidapi-host": "wnba-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

pp.pprint(response.json())
# Out:
# {'id': 401244185,
#  'players': [{'displayOrder': 1,
#               'statistics': [{'athletes': [{'active': False,
#                                             'athlete': {'displayName': 'Angel '
#                                                                        'McCoughtry',
#                                                         'guid': '6d80f287-6d06-b6c4-fda2-ed198b94434c',
#                                                         'headshot': {'alt': 'Angel '
#                                                                             'McCoughtry',
#                                                                      'href': 'https://a.espncdn.com/i/headshots/wnba/players/full/872.png'},
#                                                         'id': '872',
#                                                         'jersey': '35',
#                                                         'links': [{'href': 'https://www.espn.com/wnba/player/_/id/872/angel-mccoughtry',
# ...

# %%
import requests
import pprint as pp

url = "https://wnba-api.p.rapidapi.com/wnbateamlist"

querystring = {"limit":"10"}

headers = {
	"x-rapidapi-key": "769b17cbe4msh6c112b3e9b5c97ap1e591ejsn89cbe3f5b297",
	"x-rapidapi-host": "wnba-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

pp.pprint(response.json())
# Out:
# {'sports': [{'id': '40',
#              'leagues': [{'abbreviation': 'WNBA',
#                           'id': '59',
#                           'name': "Women's National Basketball Association",
#                           'season': {'displayName': '2025', 'year': 2025},
#                           'shortName': 'WNBA',
#                           'slug': 'wnba',
#                           'teams': [{'team': {'abbreviation': 'CONN',
#                                               'alternateColor': '0a2240',
#                                               'color': 'f05023',
#                                               'displayName': 'Connecticut Sun',
#                                               'id': '18',
#                                               'isActive': True,
#                                               'isAllStar': False,
#                                               'links': [{'href': 'https://www.espn.com/wnba/team/_/name/conn/connecticut-sun',
# ...

# %%
import requests
import pprint as pp


url = "https://wnba-api.p.rapidapi.com/team/id"

querystring = {"limit":"70"}

headers = {
	"x-rapidapi-key": "769b17cbe4msh6c112b3e9b5c97ap1e591ejsn89cbe3f5b297",
	"x-rapidapi-host": "wnba-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

pp.pprint(response.json())
# Out:
# [{'abbreviation': 'ATL',
#   'displayName': 'Atlanta Dream',
#   'link': 'https://www.espn.com/wnba/team/_/name/atl/atlanta-dream',
#   'shortDisplayName': 'Dream',
#   'slug': 'atlanta-dream',
#   'teamId': '20'},
#  {'abbreviation': 'CHI',
#   'displayName': 'Chicago Sky',
#   'link': 'https://www.espn.com/wnba/team/_/name/chi/chicago-sky',
#   'shortDisplayName': 'Sky',
#   'slug': 'chicago-sky',
#   'teamId': '19'},
#  {'abbreviation': 'CONN',
#   'displayName': 'Connecticut Sun',
#   'link': 'https://www.espn.com/wnba/team/_/name/conn/connecticut-sun',
#   'shortDisplayName': 'Sun',
#   'slug': 'connecticut-sun',
#   'teamId': '18'},
#  {'abbreviation': 'DAL',
#   'displayName': 'Dallas Wings',
#   'link': 'https://www.espn.com/wnba/team/_/name/dal/dallas-wings',
#   'shortDisplayName': 'Wings',
#   'slug': 'dallas-wings',
#   'teamId': '3'},
#  {'abbreviation': 'GSV',
#   'displayName': 'Golden State Valkyries',
# ...

# %%
import requests
import pprint as pp

url = "https://wnba-api.p.rapidapi.com/wnbaschedule"

querystring = {"year":"2025","month":"05","day":"05"}

headers = {
	"x-rapidapi-key": "769b17cbe4msh6c112b3e9b5c97ap1e591ejsn89cbe3f5b297",
	"x-rapidapi-host": "wnba-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

pp.pprint(response.json())
# Out:
# {'20250504': [{'broadcasts': [{'darkLogo': '',
#                                'link': '/watch/player/_/eventCalendarId/401761354',
#                                'logo': 'https://a.espncdn.com/guid/335fd2d2-97b9-336b-81ee-573eb6bdcffc/logos/default.png',
#                                'market': 'National',
#                                'name': 'ESPN',
#                                'type': '1'}],
#                'competitors': [{'abbrev': 'IND',
#                                 'altColor': 'e03a3e',
#                                 'displayName': 'Indiana Fever',
#                                 'id': '5',
#                                 'isHome': True,
#                                 'leader': {'displayValue': '17',
#                                            'href': 'https://www.espn.com/wnba/player/_/id/3142191/kelsey-mitchell',
#                                            'name': 'Kelsey Mitchell',
# ...
